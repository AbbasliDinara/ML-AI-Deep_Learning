# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# %%
df = [
    ['apple', 'banana', 'orange', 'grape'],
    ['bread', 'butter', 'honey', 'jam'],
    ['cheese', 'wine', 'grapes', 'olives'],
    ['carrot', 'lettuce', 'tomato', 'cucumber', 'spinach'],
    ['beef', 'potatoes', 'onion', 'garlic', 'bell pepper'],
    ['butter', 'cheese', 'tomato', 'mushrooms', 'bacon'],
    ['soda', 'chips', 'candy', 'gum', 'cookies'],
    ['salmon', 'avocado', 'lettuce', 'tomato', 'cucumber'],
    ['cereal', 'milk', 'cheese', 'butter', 'almonds'],
    ['chicken', 'rice', 'broccoli', 'carrot', 'lemon'],
    ['butter', 'potatoes', 'wine', 'cheese', 'rosemary'],
    ['apple', 'cinnamon', 'sugar', 'butter', 'nutmeg'],
    ['eggplant', 'tomato', 'onion', 'garlic', 'parsley'],
    ['spaghetti', 'meatballs', 'tomato sauce', 'garlic', 'basil'],
    ['ice cream', 'chocolate', 'strawberry', 'vanilla', 'syrup'],
    ['yogurt', 'granola', 'blueberries', 'honey', 'coconut'],
    ['peanut butter', 'jelly', 'bread', 'banana', 'honey'],
    ['butter', 'cheese', 'tomato sauce', 'basil', 'garlic'],
    ['peach', 'cream', 'sugar', 'butter', 'cinnamon'],
    ['avocado', 'egg', 'cheese', 'toast', 'bacon'],
    ['pumpkin', 'carrot', 'onion', 'potatoes', 'garlic'],
    ['cabbage', 'carrot', 'onion', 'potatoes', 'beef'],
    ['butter', 'maple syrup', 'cheese', 'strawberries', 'whipped cream'],
    ['fried chicken', 'fries', 'coleslaw', 'pickles', 'buttermilk'],
    ['burger', 'cheese', 'lettuce', 'tomato', 'onion'],
    ['sushi', 'salmon', 'rice', 'seaweed', 'avocado'],
    ['french fries', 'ketchup', 'mayonnaise', 'cheese', 'bacon'],
    ['bagel', 'cream cheese', 'smoked salmon', 'onion', 'capers'],
    ['tacos', 'beef', 'cheese', 'lettuce', 'sour cream'],
    ['salad', 'chicken', 'avocado', 'tomato', 'olives'],
    ['smoothie', 'banana', 'spinach', 'almonds', 'blueberries'],
    ['chocolate cake', 'butter', 'flour', 'sugar', 'cocoa powder'],
    ['cheeseburger', 'lettuce', 'tomato', 'pickles', 'ketchup'],
    ['grilled cheese', 'tomato soup', 'butter', 'bread', 'cheese'],
    ['latte', 'coffee', 'milk', 'sugar', 'cinnamon'],
    ['baguette', 'cheese', 'wine', 'olives', 'prosciutto'],
    ['roast chicken', 'potatoes', 'garlic', 'lemon', 'rosemary'],
    ['sliced ham', 'cheese', 'bread', 'mustard', 'pickles'],
    ['chicken wings', 'hot sauce', 'celery', 'blue cheese', 'carrot'],
    ['beef stew', 'potatoes', 'onion', 'carrot', 'garlic'],
    ['pork ribs', 'bbq sauce', 'coleslaw', 'cornbread', 'pickle'],
    ['pasta', 'cream', 'garlic', 'parmesan', 'bacon'],
    ['mango', 'pineapple', 'coconut', 'lime', 'sugar'],
    ['soup', 'tomato', 'carrot', 'onion', 'celery'],
    ['fish tacos', 'avocado', 'tomato', 'lime', 'cabbage'],
    ['grilled salmon', 'lemon', 'garlic', 'olive oil', 'rosemary'],
    ['chocolate chip cookies', 'butter', 'flour', 'sugar', 'chocolate chips'],
    ['veggie burger', 'lettuce', 'tomato', 'cheese', 'pickle'],
    ['chicken curry', 'coconut milk', 'rice', 'turmeric', 'coriander'],
    ['vegetable stir fry', 'tofu', 'soy sauce', 'ginger', 'garlic'],
    ['quinoa', 'butter', 'cherry tomatoes', 'cucumber', 'cheese'],
    ['falafel', 'hummus', 'pita', 'tomato', 'cucumber'],
    ['cheese', 'wine', 'bread', 'butter', 'olives'],
    ['coconut milk', 'chicken', 'rice', 'ginger', 'garlic'],
    ['tomato', 'lettuce', 'onion', 'cheese', 'avocado'],
    ['chicken', 'butter', 'avocado', 'lettuce', 'cheese'],
    ['pasta', 'tomato sauce', 'cheese', 'garlic', 'oregano'],
    ['apple', 'butter', 'cheese', 'grapes', 'watermelon'],
    ['tomato', 'onion', 'garlic', 'bell pepper', 'parsley']
]

# %%
te = TransactionEncoder()
te_data = te.fit(df).transform(df)
df_new = pd.DataFrame(te_data, columns=te.columns_)
df_new
# Out:
#     almonds  apple  avocado  bacon  bagel  baguette  banana  basil  bbq sauce  \
# 0     False   True    False  False  False     False    True  False      False
# 1     False  False    False  False  False     False   False  False      False
# 2     False  False    False  False  False     False   False  False      False
# 3     False  False    False  False  False     False   False  False      False
# 4     False  False    False  False  False     False   False  False      False
# 5     False  False    False   True  False     False   False  False      False
# 6     False  False    False  False  False     False   False  False      False
# 7     False  False     True  False  False     False   False  False      False
# 8      True  False    False  False  False     False   False  False      False
# 9     False  False    False  False  False     False   False  False      False
# 10    False  False    False  False  False     False   False  False      False
# ...

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.1,num_itemsets = 3)
rules
#confidence gosterir
## butter alinanlarinin 60 faizinde cheese alinir butter alinan  tranksiya icinden

#cheese alanlarin 50 fazii butter alir
## lettuce alanalrin 75 %i tomato alir
##lift
# >1 olanda bir birine musbet tesir gosterir alinmasi




##support
##hemin cutluk datade ne qeder gorunur ne qeder tez tez rast gelinir ki 33 faizdir umumi traskiyanin
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0    (butter)    (cheese)            0.254237            0.338983  0.169492
# 1    (cheese)    (butter)            0.338983            0.254237  0.169492
# 2   (lettuce)    (tomato)            0.135593            0.220339  0.101695
# 3    (tomato)   (lettuce)            0.220339            0.135593  0.101695
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.666667  1.966667               1.0  0.083309    1.983051
# 1    0.500000  1.966667               1.0  0.083309    1.491525
# 2    0.750000  3.403846               1.0  0.071818    3.118644
# 3    0.461538  3.403846               1.0  0.071818    1.605327
#
#    zhangs_metric  jaccard  certainty  kulczynski
# 0       0.659091      0.4   0.495726    0.583333
# 1       0.743590      0.4   0.329545    0.583333
# 2       0.816993      0.4   0.679348    0.605769
# 3       0.905797      0.4   0.377074    0.605769

# %%
#df_new = df_new.reset_index(drop=True)
'''
transactions = df_new.apply(
    lambda row: row.dropna().tolist(),
    axis=1
)
'''
##liste cevir

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_data = te.fit(df).transform(df)

# %%
te
# Out:
# TransactionEncoder()

# %%
#te_data ## 01 fromaasina getirdik

df_te = pd.DataFrame(te_data, columns=te.columns_) ##yaxsi gorek deye
df_te
# Out:
#     almonds  apple  avocado  bacon  bagel  baguette  banana  basil  bbq sauce  \
# 0     False   True    False  False  False     False    True  False      False
# 1     False  False    False  False  False     False   False  False      False
# 2     False  False    False  False  False     False   False  False      False
# 3     False  False    False  False  False     False   False  False      False
# 4     False  False    False  False  False     False   False  False      False
# 5     False  False    False   True  False     False   False  False      False
# 6     False  False    False  False  False     False   False  False      False
# 7     False  False     True  False  False     False   False  False      False
# 8      True  False    False  False  False     False   False  False      False
# 9     False  False    False  False  False     False   False  False      False
# 10    False  False    False  False  False     False   False  False      False
# ...

# %%
fp_growth = fpgrowth(df_te, min_support=0.1, use_colnames=True)
fp_growth
# Out:
#      support           itemsets
# 0   0.254237           (butter)
# 1   0.338983           (cheese)
# 2   0.220339           (tomato)
# 3   0.135593          (lettuce)
# 4   0.118644           (carrot)
# 5   0.220339           (garlic)
# 6   0.169492            (onion)
# 7   0.101695         (potatoes)
# 8   0.118644          (avocado)
# 9   0.101695            (sugar)
# 10  0.169492   (butter, cheese)
# 11  0.101695  (lettuce, tomato)
